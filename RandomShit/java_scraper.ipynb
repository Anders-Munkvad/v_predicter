# %%
import chromedriver_autoinstaller
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.chrome.options import Options

#chromedriver_autoinstaller.install()

# %%
# NOTE: <div class="searchstyles__ItemRow-sc-ci5zlg-4 iZJlqR">

# https://medium.com/thedevproject/how-to-scrape-javascript-heavy-sites-like-a-pro-with-python-1ecf6f829538

# Request web pages:
# Set up options for Chrome
chrome_options = Options()
chrome_options.add_argument('--headless')  # Run in headless mode
chrome_options.add_argument('--disable-gpu')  # Disable GPU acceleration

driver = webdriver.Chrome()

# GET:
driver.get('https://www.coindesk.com/search?s=bitcoin')

#HTML:
html = driver.page_source

# Parse HTML:
soup = BeautifulSoup(html, 'html.parser')

articles = soup.find_all('div', 'searchstyles__ItemRow-sc-ci5zlg-4 iZJlqR')

print(articles)

#for article in articles:
#    title = article.find(' ', )
# Out:
# [<div class="searchstyles__ItemRow-sc-ci5zlg-4 iZJlqR"><div class="searchstyles__ItemLink-sc-ci5zlg-5 jbtbqV"><div class="searchstyles__SearchCardWrapper-sc-ci5zlg-21 jjGJEL"><a class="searchstyles__ImageContainer-sc-ci5zlg-7 liSNgC" href="/price/bitcoin"><img alt="Logo of BTC" class="" height="24" loading="lazy" src="https://cloudfront-us-east-1.images.arcpublishing.com/coindesk/S3ODTTWSMFCFTJZD3K5K5OX5HI.png" width="24"/></a><div class="Box-sc-1hpkeeg-0 edKURV" display="flex" style="flex-direction: column;"><a class="Box-sc-1hpkeeg-0 hmLHIZ" href="/data" style="color: rgb(26, 137, 23);"><h6 class="typography__StyledTypography-sc-owin6q-0 loODNJ capitalize">Crypto Prices</h6></a><a class="Box-sc-1hpkeeg-0 bdAcJT" href="/price/bitcoin" style="text-decoration: none;"><h3 class="typography__StyledTypography-sc-owin6q-0 fQpXzJ">Bitcoin</h3><h6 class="typography__StyledTypography-sc-owin6q-0 iFShfU" style="color: rgba(38, 38, 38, 0.55); margin-left: 5px;">BTC</h6></a><a class="Box-sc-1hp
# ...
